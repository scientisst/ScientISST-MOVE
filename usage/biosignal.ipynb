# %% [markdown]
# # ScientISST MOVE: Getting Started with LTBio
# Please cite:
# _Saraiva et al., ScientISST MOVE: Annotated Multimodal Naturalistic Dataset Recorded During Everyday Life Activities Using Wearable Devices, Scientific Data (2024)_

# %% [markdown]
# **It is recommended you run this notebook in a virtual environment.**
# On the terminal:
#
# 1. Create new virtual environment: `python -m venv venv`
# 2. Activate it: `source venv/bin/activate` on Linux/MacOS or `venv\Scripts\activate` on Windows
# 3. Associate this to a Jupyter kernel: `ipython kernel install --user --name=venv`
# 4. Restart the notebook and change the kernel to `venv` under the Kernel tab.
#
# See full guide [here](https://www.geeksforgeeks.org/using-jupyter-notebook-in-virtual-environment/).

# %% [markdown]
# ## A. Download Dataset
#
# This might take a while...
# Bellow, you might need to change to pip3 or pip, depending on your system.

# %%
# !pip3 install wget
import wget, zipfile, os, ssl
ssl._create_default_https_context = ssl._create_unverified_context

# Download dataset in LTBio format
url = 'https://zenodo.org/records/10114104/files/biosignal.zip?download=1'
filename = wget.download(url)  # into to the current directory

# Decompress zip file
with zipfile.ZipFile(filename, 'r') as zip_ref:
    for file in zip_ref.namelist():
        if file.startswith('biosignal/'):
            zip_ref.extract(file)

# Delete zip file
os.remove(filename)

# %% [markdown]
# ## B. Install LTBio
# Bellow, you might need to change to pip3 or pip, depending on your system.

# %%
# !pip install LongTermBiosignals  # comment this if already installed
# Out:
# Collecting LongTermBiosignals
#   Downloading LongTermBiosignals-2.0.2-py3-none-any.whl.metadata (12 kB)
# Collecting alabaster==0.7.12 (from LongTermBiosignals)
#   Downloading alabaster-0.7.12-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting altair==4.2.0 (from LongTermBiosignals)
#   Downloading altair-4.2.0-py3-none-any.whl.metadata (13 kB)
# Collecting appdirs==1.4.4 (from LongTermBiosignals)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting appnope==0.1.3 (from LongTermBiosignals)
#   Downloading appnope-0.1.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting argon2-cffi==21.3.0 (from LongTermBiosignals)
#   Downloading argon2_cffi-21.3.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting argon2-cffi-bindings==21.2.0 (from LongTermBiosignals)
#   Downloading argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl.metadata (6.7 kB)
# Collecting astroid==2.11.5 (from LongTermBiosignals)
#   Downloading astroid-2.11.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting asttokens==2.0.5 (from LongTermBiosignals)
#   Downloading asttokens-2.0.5-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting attrs==21.4.0 (from LongTermBiosignals)
#   Downloading attrs-21.4.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting Babel==2.10.3 (from LongTermBiosignals)
#   Downloading Babel-2.10.3-py3-none-any.whl.metadata (1.3 kB)
# Collecting backcall==0.2.0 (from LongTermBiosignals)
#   Downloading backcall-0.2.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting backoff==1.11.1 (from LongTermBiosignals)
#   Downloading backoff-1.11.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting beautifulsoup4==4.11.1 (from LongTermBiosignals)
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting bidict==0.22.0 (from LongTermBiosignals)
#   Downloading bidict-0.22.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting biosppy==0.8.0 (from LongTermBiosignals)
#   Downloading biosppy-0.8.0.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 12.8 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting bleach==5.0.1 (from LongTermBiosignals)
#   Downloading bleach-5.0.1-py3-none-any.whl.metadata (27 kB)
# Collecting bokeh==2.4.3 (from LongTermBiosignals)
#   Downloading bokeh-2.4.3-py3-none-any.whl.metadata (14 kB)
# Collecting boltons==21.0.0 (from LongTermBiosignals)
#   Downloading boltons-21.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting certifi==2021.10.8 (from LongTermBiosignals)
#   Downloading certifi-2021.10.8-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting cffi==1.15.0 (from LongTermBiosignals)
#   Downloading cffi-1.15.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (1.2 kB)
# Collecting cftime==1.6.3 (from LongTermBiosignals)
#   Downloading cftime-1.6.3-cp310-cp310-macosx_10_9_x86_64.whl.metadata (8.6 kB)
# Collecting chardet==4.0.0 (from LongTermBiosignals)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting charset-normalizer==2.0.12 (from LongTermBiosignals)
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl.metadata (11 kB)
# Collecting click==8.1.3 (from LongTermBiosignals)
#   Downloading click-8.1.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting click-spinner==0.1.10 (from LongTermBiosignals)
#   Downloading click_spinner-0.1.10-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting colorlog==6.7.0 (from LongTermBiosignals)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting colorspacious==1.1.2 (from LongTermBiosignals)
#   Downloading colorspacious-1.1.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting commonmark==0.9.1 (from LongTermBiosignals)
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting cramjam==2.5.0 (from LongTermBiosignals)
#   Downloading cramjam-2.5.0-cp310-cp310-macosx_10_9_x86_64.macosx_11_0_arm64.macosx_10_9_universal2.whl.metadata (3.4 kB)
# Collecting cycler==0.11.0 (from LongTermBiosignals)
#   Downloading cycler-0.11.0-py3-none-any.whl.metadata (785 bytes)
# Collecting Cython==0.29.32 (from LongTermBiosignals)
#   Downloading Cython-0.29.32-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting dacite==1.6.0 (from LongTermBiosignals)
#   Downloading dacite-1.6.0-py3-none-any.whl.metadata (14 kB)
# Collecting darkdetect==0.8.0 (from LongTermBiosignals)
#   Downloading darkdetect-0.8.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting datacommons==1.4.3 (from LongTermBiosignals)
#   Downloading datacommons-1.4.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting datacommons-pandas==0.0.3 (from LongTermBiosignals)
#   Downloading datacommons_pandas-0.0.3-py3-none-any.whl.metadata (2.3 kB)
# Collecting datapane==0.15.3 (from LongTermBiosignals)
#   Downloading datapane-0.15.3-py3-none-any.whl.metadata (9.4 kB)
# Collecting DateTime==5.1 (from LongTermBiosignals)
#   Downloading DateTime-5.1-py3-none-any.whl.metadata (32 kB)
# Collecting DateTimeRange==1.2.0 (from LongTermBiosignals)
#   Downloading DateTimeRange-1.2.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting debugpy==1.6.0 (from LongTermBiosignals)
#   Downloading debugpy-1.6.0-cp310-cp310-macosx_10_15_x86_64.whl.metadata (1.1 kB)
# Collecting decorator==5.1.1 (from LongTermBiosignals)
#   Downloading decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting defusedxml==0.7.1 (from LongTermBiosignals)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting diagrams==0.21.1 (from LongTermBiosignals)
#   Downloading diagrams-0.21.1-py3-none-any.whl.metadata (7.0 kB)
# Collecting dill==0.3.4 (from LongTermBiosignals)
#   Downloading dill-0.3.4-py2.py3-none-any.whl.metadata (9.6 kB)
# Collecting docutils==0.18.1 (from LongTermBiosignals)
#   Downloading docutils-0.18.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting dominate==2.7.0 (from LongTermBiosignals)
#   Downloading dominate-2.7.0-py2.py3-none-any.whl.metadata (13 kB)
# Collecting dulwich==0.20.46 (from LongTermBiosignals)
#   Downloading dulwich-0.20.46-cp310-cp310-macosx_10_15_x86_64.whl.metadata (4.2 kB)
# Collecting edflib==0.84.1 (from LongTermBiosignals)
#   Using cached edflib-0.84.1-cp310-cp310-macosx_10_9_universal2.whl
# Collecting EDFlib-Python==1.0.6 (from LongTermBiosignals)
#   Downloading EDFlib_Python-1.0.6-py3-none-any.whl.metadata (1.3 kB)
# Collecting entrypoints==0.4 (from LongTermBiosignals)
#   Downloading entrypoints-0.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting executing==0.8.3 (from LongTermBiosignals)
#   Downloading executing-0.8.3-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting face==20.1.1 (from LongTermBiosignals)
#   Downloading face-20.1.1-py3-none-any.whl.metadata (868 bytes)
# Collecting fastjsonschema==2.15.3 (from LongTermBiosignals)
#   Downloading fastjsonschema-2.15.3-py3-none-any.whl.metadata (1.9 kB)
# Collecting fastparquet==0.8.3 (from LongTermBiosignals)
#   Downloading fastparquet-0.8.3-cp310-cp310-macosx_10_9_universal2.whl.metadata (4.1 kB)
# Collecting flake8==5.0.4 (from LongTermBiosignals)
#   Downloading flake8-5.0.4-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting fonttools==4.33.2 (from LongTermBiosignals)
#   Downloading fonttools-4.33.2-py3-none-any.whl.metadata (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.3/125.3 kB 3.6 MB/s eta 0:00:00
# Collecting fpdf2==2.5.5 (from LongTermBiosignals)
#   Downloading fpdf2-2.5.5-py2.py3-none-any.whl.metadata (28 kB)
# Collecting fsspec==2022.8.2 (from LongTermBiosignals)
#   Downloading fsspec-2022.8.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting furl==2.1.3 (from LongTermBiosignals)
#   Downloading furl-2.1.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting furo==2022.12.7 (from LongTermBiosignals)
#   Downloading furo-2022.12.7-py3-none-any.whl.metadata (6.0 kB)
# Collecting future==0.18.2 (from LongTermBiosignals)
#   Downloading future-0.18.2.tar.gz (829 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.2/829.2 kB 14.1 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting gitdb==4.0.9 (from LongTermBiosignals)
#   Downloading gitdb-4.0.9-py3-none-any.whl.metadata (998 bytes)
# Collecting GitPython==3.1.27 (from LongTermBiosignals)
#   Downloading GitPython-3.1.27-py3-none-any.whl.metadata (1.3 kB)
# Collecting glom==22.1.0 (from LongTermBiosignals)
#   Downloading glom-22.1.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Collecting graphviz==0.19.2 (from LongTermBiosignals)
#   Downloading graphviz-0.19.2-py3-none-any.whl.metadata (11 kB)
# Collecting h5py==3.7.0 (from LongTermBiosignals)
#   Downloading h5py-3.7.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (1.8 kB)
# Collecting idna==3.3 (from LongTermBiosignals)
#   Downloading idna-3.3-py3-none-any.whl.metadata (9.8 kB)
# Collecting imagesize==1.4.1 (from LongTermBiosignals)
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting importlib-metadata==4.12.0 (from LongTermBiosignals)
#   Downloading importlib_metadata-4.12.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting importlib-resources==5.9.0 (from LongTermBiosignals)
#   Downloading importlib_resources-5.9.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting infinity==1.5 (from LongTermBiosignals)
#   Downloading infinity-1.5.tar.gz (5.4 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting iniconfig==1.1.1 (from LongTermBiosignals)
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting ipykernel==6.15.0 (from LongTermBiosignals)
#   Downloading ipykernel-6.15.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting ipython==8.4.0 (from LongTermBiosignals)
#   Downloading ipython-8.4.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting ipython-genutils==0.2.0 (from LongTermBiosignals)
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Collecting ipywidgets==7.7.1 (from LongTermBiosignals)
#   Downloading ipywidgets-7.7.1-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting isort==5.10.1 (from LongTermBiosignals)
#   Downloading isort-5.10.1-py3-none-any.whl.metadata (12 kB)
# Collecting jedi==0.18.1 (from LongTermBiosignals)
#   Downloading jedi-0.18.1-py2.py3-none-any.whl.metadata (20 kB)
# Collecting Jinja2==3.1.1 (from LongTermBiosignals)
#   Downloading Jinja2-3.1.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting joblib==1.1.0 (from LongTermBiosignals)
#   Downloading joblib-1.1.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting jsonschema==4.6.0 (from LongTermBiosignals)
#   Downloading jsonschema-4.6.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting jupyter==1.0.0 (from LongTermBiosignals)
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl.metadata (995 bytes)
# Collecting jupyter-client==7.3.4 (from LongTermBiosignals)
#   Downloading jupyter_client-7.3.4-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyter-console==6.4.4 (from LongTermBiosignals)
#   Downloading jupyter_console-6.4.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting jupyter-core==4.10.0 (from LongTermBiosignals)
#   Downloading jupyter_core-4.10.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting jupyterlab-pygments==0.2.2 (from LongTermBiosignals)
#   Downloading jupyterlab_pygments-0.2.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting jupyterlab-widgets==1.1.1 (from LongTermBiosignals)
#   Downloading jupyterlab_widgets-1.1.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting keyring==23.7.0 (from LongTermBiosignals)
#   Downloading keyring-23.7.0-py3-none-any.whl.metadata (19 kB)
# Collecting kiwisolver==1.4.2 (from LongTermBiosignals)
#   Downloading kiwisolver-1.4.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (6.4 kB)
# Collecting lazy-object-proxy==1.7.1 (from LongTermBiosignals)
#   Downloading lazy_object_proxy-1.7.1-cp310-cp310-macosx_10_9_x86_64.whl.metadata (6.8 kB)
# Collecting lazy-loader==0.3 (from LongTermBiosignals)
#   Downloading lazy_loader-0.3-py3-none-any.whl.metadata (4.3 kB)
# Collecting littleutils==0.2.2 (from LongTermBiosignals)
#   Using cached littleutils-0.2.2-py3-none-any.whl
# Collecting lxml==4.9.1 (from LongTermBiosignals)
#   Downloading lxml-4.9.1.tar.gz (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 28.8 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting markdown-it-py==2.1.0 (from LongTermBiosignals)
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting MarkupSafe==2.1.1 (from LongTermBiosignals)
#   Downloading MarkupSafe-2.1.1-cp310-cp310-macosx_10_9_x86_64.whl.metadata (3.2 kB)
# Collecting matplotlib==3.5.1 (from LongTermBiosignals)
#   Downloading matplotlib-3.5.1-cp310-cp310-macosx_10_9_x86_64.whl.metadata (6.7 kB)
# Collecting matplotlib-inline==0.1.3 (from LongTermBiosignals)
#   Downloading matplotlib_inline-0.1.3-py3-none-any.whl.metadata (397 bytes)
# Collecting mbstrdecoder==1.1.0 (from LongTermBiosignals)
#   Downloading mbstrdecoder-1.1.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting mccabe==0.7.0 (from LongTermBiosignals)
#   Downloading mccabe-0.7.0-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting mdit-py-plugins==0.3.3 (from LongTermBiosignals)
#   Downloading mdit_py_plugins-0.3.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting mdurl==0.1.2 (from LongTermBiosignals)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting micawber==0.5.4 (from LongTermBiosignals)
#   Downloading micawber-0.5.4.tar.gz (18 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting mistune==0.8.4 (from LongTermBiosignals)
#   Downloading mistune-0.8.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting mne (from LongTermBiosignals)
#   Downloading mne-1.6.1-py3-none-any.whl.metadata (13 kB)
# Collecting mne-connectivity (from LongTermBiosignals)
#   Downloading mne_connectivity-0.6.0-py3-none-any.whl.metadata (10 kB)
# Collecting mne-qt-browser==0.6.1 (from LongTermBiosignals)
#   Downloading mne_qt_browser-0.6.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting monotonic==1.6 (from LongTermBiosignals)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting multimethod==1.9.1 (from LongTermBiosignals)
#   Downloading multimethod-1.9.1-py3-none-any.whl.metadata (9.2 kB)
# Collecting multipledispatch==0.6.0 (from LongTermBiosignals)
#   Downloading multipledispatch-0.6.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting munch==2.5.0 (from LongTermBiosignals)
#   Downloading munch-2.5.0-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting myst-parser==0.18.1 (from LongTermBiosignals)
#   Downloading myst_parser-0.18.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting nbclient==0.6.4 (from LongTermBiosignals)
#   Downloading nbclient-0.6.4-py3-none-any.whl.metadata (5.1 kB)
# Collecting nbconvert==6.5.0 (from LongTermBiosignals)
#   Downloading nbconvert-6.5.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting nbformat==5.4.0 (from LongTermBiosignals)
#   Downloading nbformat-5.4.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting neo==0.10.2 (from LongTermBiosignals)
#   Downloading neo-0.10.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting nest-asyncio==1.5.5 (from LongTermBiosignals)
#   Downloading nest_asyncio-1.5.5-py3-none-any.whl.metadata (2.7 kB)
# Collecting netCDF4==1.6.5 (from LongTermBiosignals)
#   Downloading netCDF4-1.6.5-cp310-cp310-macosx_10_9_x86_64.whl.metadata (1.8 kB)
# Collecting notebook==6.4.12 (from LongTermBiosignals)
#   Downloading notebook-6.4.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting numexpr==2.8.3 (from LongTermBiosignals)
#   Downloading numexpr-2.8.3-cp310-cp310-macosx_10_9_x86_64.whl.metadata (7.9 kB)
# Collecting numpy==1.22.3 (from LongTermBiosignals)
#   Downloading numpy-1.22.3-cp310-cp310-macosx_10_14_x86_64.whl.metadata (2.0 kB)
# Collecting opencv-python==4.5.5.64 (from LongTermBiosignals)
#   Downloading opencv_python-4.5.5.64-cp36-abi3-macosx_10_15_x86_64.whl.metadata (18 kB)
# Collecting orderedmultidict==1.0.1 (from LongTermBiosignals)
#   Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting outdated==0.2.2 (from LongTermBiosignals)
#   Downloading outdated-0.2.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting packaging==21.3 (from LongTermBiosignals)
#   Downloading packaging-21.3-py3-none-any.whl.metadata (15 kB)
# Collecting pandas==1.4.2 (from LongTermBiosignals)
#   Downloading pandas-1.4.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (12 kB)
# Collecting pandas-flavor==0.6.0 (from LongTermBiosignals)
#   Downloading pandas_flavor-0.6.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting pandocfilters==1.5.0 (from LongTermBiosignals)
#   Downloading pandocfilters-1.5.0-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting parso==0.8.3 (from LongTermBiosignals)
#   Downloading parso-0.8.3-py2.py3-none-any.whl.metadata (7.5 kB)
# Collecting patsy==0.5.2 (from LongTermBiosignals)
#   Downloading patsy-0.5.2-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting pexpect==4.8.0 (from LongTermBiosignals)
#   Downloading pexpect-4.8.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting pickleshare==0.7.5 (from LongTermBiosignals)
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting Pillow==9.1.0 (from LongTermBiosignals)
#   Downloading Pillow-9.1.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (8.7 kB)
# Collecting pingouin==0.5.3 (from LongTermBiosignals)
#   Downloading pingouin-0.5.3-py3-none-any.whl.metadata (1.2 kB)
# Collecting pkginfo==1.8.3 (from LongTermBiosignals)
#   Downloading pkginfo-1.8.3-py2.py3-none-any.whl.metadata (9.9 kB)
# Collecting platformdirs==2.5.2 (from LongTermBiosignals)
#   Downloading platformdirs-2.5.2-py3-none-any.whl.metadata (9.4 kB)
# Collecting plotly==5.10.0 (from LongTermBiosignals)
#   Downloading plotly-5.10.0-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting plotly-express==0.4.1 (from LongTermBiosignals)
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting pluggy==1.0.0 (from LongTermBiosignals)
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl.metadata (4.3 kB)
# Collecting ply==3.11 (from LongTermBiosignals)
#   Downloading ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Collecting pooch==1.6.0 (from LongTermBiosignals)
#   Downloading pooch-1.6.0-py3-none-any.whl.metadata (10 kB)
# Collecting posthog==2.1.2 (from LongTermBiosignals)
#   Downloading posthog-2.1.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting prometheus-client==0.14.1 (from LongTermBiosignals)
#   Downloading prometheus_client-0.14.1-py3-none-any.whl.metadata (21 kB)
# Collecting prompt-toolkit==3.0.30 (from LongTermBiosignals)
#   Downloading prompt_toolkit-3.0.30-py3-none-any.whl.metadata (7.1 kB)
# Collecting psutil==5.9.1 (from LongTermBiosignals)
#   Downloading psutil-5.9.1-cp310-cp310-macosx_10_9_x86_64.whl.metadata (21 kB)
# Collecting ptyprocess==0.7.0 (from LongTermBiosignals)
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting pure-eval==0.2.2 (from LongTermBiosignals)
#   Downloading pure_eval-0.2.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting py==1.11.0 (from LongTermBiosignals)
#   Downloading py-1.11.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting py-cpuinfo==8.0.0 (from LongTermBiosignals)
#   Downloading py-cpuinfo-8.0.0.tar.gz (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.8/99.8 kB 3.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyarrow==6.0.1 (from LongTermBiosignals)
#   Downloading pyarrow-6.0.1-cp310-cp310-macosx_10_13_x86_64.whl.metadata (2.9 kB)
# Collecting pycodestyle==2.9.1 (from LongTermBiosignals)
#   Downloading pycodestyle-2.9.1-py2.py3-none-any.whl.metadata (31 kB)
# Collecting pycparser==2.21 (from LongTermBiosignals)
#   Downloading pycparser-2.21-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting pydantic==1.10.2 (from LongTermBiosignals)
#   Downloading pydantic-1.10.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.0/140.0 kB 3.2 MB/s eta 0:00:00a 0:00:01
# Collecting pyEDFlib==0.1.30 (from LongTermBiosignals)
#   Downloading pyEDFlib-0.1.30-cp310-cp310-macosx_10_9_x86_64.whl.metadata (6.3 kB)
# Collecting pyflakes==2.5.0 (from LongTermBiosignals)
#   Downloading pyflakes-2.5.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting Pygments==2.12.0 (from LongTermBiosignals)
#   Downloading Pygments-2.12.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting pylint==2.13.9 (from LongTermBiosignals)
#   Downloading pylint-2.13.9-py3-none-any.whl.metadata (8.9 kB)
# Collecting pymatreader==0.0.32 (from LongTermBiosignals)
#   Downloading pymatreader-0.0.32-py3-none-any.whl.metadata (1.4 kB)
# Collecting Pympler==1.0.1 (from LongTermBiosignals)
#   Downloading Pympler-1.0.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting PyOpenGL==3.1.7 (from LongTermBiosignals)
#   Downloading PyOpenGL-3.1.7-py3-none-any.whl.metadata (3.2 kB)
# Collecting pyparsing==3.0.8 (from LongTermBiosignals)
#   Downloading pyparsing-3.0.8-py3-none-any.whl.metadata (4.2 kB)
# Collecting PyQt5 (from LongTermBiosignals)
#   Downloading PyQt5-5.15.10-cp37-abi3-macosx_10_13_x86_64.whl.metadata (2.1 kB)
# Collecting PyQt5-Qt5 (from LongTermBiosignals)
#   Downloading PyQt5_Qt5-5.15.12-py3-none-macosx_10_13_x86_64.whl.metadata (536 bytes)
# Collecting PyQt5-sip (from LongTermBiosignals)
#   Downloading PyQt5_sip-12.13.0-cp310-cp310-macosx_10_9_universal2.whl.metadata (504 bytes)
# Collecting pyqtgraph (from LongTermBiosignals)
#   Downloading pyqtgraph-0.13.4-py3-none-any.whl.metadata (1.3 kB)
# Collecting pyrsistent==0.18.1 (from LongTermBiosignals)
#   Downloading pyrsistent-0.18.1-cp310-cp310-macosx_10_9_universal2.whl.metadata (26 kB)
# Collecting pytest==7.1.2 (from LongTermBiosignals)
#   Downloading pytest-7.1.2-py3-none-any.whl.metadata (7.8 kB)
# Collecting python-dateutil==2.8.2 (from LongTermBiosignals)
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl.metadata (8.2 kB)
# Collecting pytz==2022.1 (from LongTermBiosignals)
#   Downloading pytz-2022.1-py2.py3-none-any.whl.metadata (21 kB)
# Collecting PyYAML==6.0 (from LongTermBiosignals)
#   Downloading PyYAML-6.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (2.0 kB)
# Collecting pyzmq==23.2.0 (from LongTermBiosignals)
#   Downloading pyzmq-23.2.0-cp310-cp310-macosx_10_15_universal2.whl.metadata (4.8 kB)
# Collecting QDarkStyle==3.2.3 (from LongTermBiosignals)
#   Downloading QDarkStyle-3.2.3-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting qtconsole==5.3.1 (from LongTermBiosignals)
#   Downloading qtconsole-5.3.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting QtPy==2.1.0 (from LongTermBiosignals)
#   Downloading QtPy-2.1.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting quantities==0.13.0 (from LongTermBiosignals)
#   Downloading quantities-0.13.0.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.8 MB/s eta 0:00:00ta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting readme-renderer==35.0 (from LongTermBiosignals)
#   Downloading readme_renderer-35.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting requests==2.27.1 (from LongTermBiosignals)
#   Downloading requests-2.27.1-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting requests-toolbelt==0.9.1 (from LongTermBiosignals)
#   Downloading requests_toolbelt-0.9.1-py2.py3-none-any.whl.metadata (13 kB)
# Collecting rfc3986==2.0.0 (from LongTermBiosignals)
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting rich==12.5.1 (from LongTermBiosignals)
#   Downloading rich-12.5.1-py3-none-any.whl.metadata (18 kB)
# Collecting scikit-learn==1.1.0 (from LongTermBiosignals)
#   Downloading scikit_learn-1.1.0-cp310-cp310-macosx_10_13_x86_64.whl.metadata (10 kB)
# Collecting scipy==1.8.0 (from LongTermBiosignals)
#   Downloading scipy-1.8.0-cp310-cp310-macosx_12_0_universal2.macosx_10_9_x86_64.whl.metadata (2.2 kB)
# Collecting scooby==0.9.2 (from LongTermBiosignals)
#   Downloading scooby-0.9.2-py3-none-any.whl.metadata (15 kB)
# Collecting seaborn==0.11.2 (from LongTermBiosignals)
#   Downloading seaborn-0.11.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting Send2Trash==1.8.0 (from LongTermBiosignals)
#   Downloading Send2Trash-1.8.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting shortuuid==1.0.9 (from LongTermBiosignals)
#   Downloading shortuuid-1.0.9-py3-none-any.whl.metadata (5.7 kB)
# Collecting six==1.16.0 (from LongTermBiosignals)
#   Downloading six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting smmap==5.0.0 (from LongTermBiosignals)
#   Downloading smmap-5.0.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting snowballstemmer==2.2.0 (from LongTermBiosignals)
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting sortedcontainers==2.4.0 (from LongTermBiosignals)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting soupsieve==2.3.2.post1 (from LongTermBiosignals)
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl.metadata (5.7 kB)
# Collecting Sphinx==5.0.2 (from LongTermBiosignals)
#   Downloading Sphinx-5.0.2-py3-none-any.whl.metadata (7.9 kB)
# Collecting sphinx-autoapi==2.0.1 (from LongTermBiosignals)
#   Downloading sphinx_autoapi-2.0.1-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting sphinx-basic-ng==1.0.0b1 (from LongTermBiosignals)
#   Downloading sphinx_basic_ng-1.0.0b1-py3-none-any.whl.metadata (1.5 kB)
# Collecting sphinx-copybutton==0.5.1 (from LongTermBiosignals)
#   Downloading sphinx_copybutton-0.5.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting sphinxcontrib-applehelp==1.0.2 (from LongTermBiosignals)
#   Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting sphinxcontrib-devhelp==1.0.2 (from LongTermBiosignals)
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting sphinxcontrib-htmlhelp==2.0.0 (from LongTermBiosignals)
#   Downloading sphinxcontrib_htmlhelp-2.0.0-py2.py3-none-any.whl.metadata (1.6 kB)
# Collecting sphinxcontrib-jsmath==1.0.1 (from LongTermBiosignals)
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting sphinxcontrib-qthelp==1.0.3 (from LongTermBiosignals)
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting sphinxcontrib-serializinghtml==1.1.5 (from LongTermBiosignals)
#   Downloading sphinxcontrib_serializinghtml-1.1.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting stack-data==0.3.0 (from LongTermBiosignals)
#   Downloading stack_data-0.3.0-py3-none-any.whl.metadata (18 kB)
# Collecting statsmodels==0.13.2 (from LongTermBiosignals)
#   Downloading statsmodels-0.13.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (8.1 kB)
# Collecting stringcase==1.2.0 (from LongTermBiosignals)
#   Downloading stringcase-1.2.0.tar.gz (3.0 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting tables==3.7.0 (from LongTermBiosignals)
#   Downloading tables-3.7.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (2.0 kB)
# Collecting tabulate==0.8.10 (from LongTermBiosignals)
#   Downloading tabulate-0.8.10-py3-none-any.whl.metadata (25 kB)
# Collecting tenacity==8.1.0 (from LongTermBiosignals)
#   Downloading tenacity-8.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting terminado==0.15.0 (from LongTermBiosignals)
#   Downloading terminado-0.15.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl==3.1.0 (from LongTermBiosignals)
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting thriftpy2==0.4.14 (from LongTermBiosignals)
#   Downloading thriftpy2-0.4.14.tar.gz (361 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.7/361.7 kB 8.2 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting tinycss2==1.1.1 (from LongTermBiosignals)
#   Downloading tinycss2-1.1.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting tomli==2.0.1 (from LongTermBiosignals)
#   Downloading tomli-2.0.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting toolz==0.12.0 (from LongTermBiosignals)
#   Downloading toolz-0.12.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting torch==1.13.1 (from LongTermBiosignals)
#   Downloading torch-1.13.1-cp310-none-macosx_10_9_x86_64.whl.metadata (23 kB)
# Collecting torchmetrics==0.10.0 (from LongTermBiosignals)
#   Downloading torchmetrics-0.10.0-py3-none-any.whl.metadata (15 kB)
# Collecting torchsummary==1.5.1 (from LongTermBiosignals)
#   Downloading torchsummary-1.5.1-py3-none-any.whl.metadata (296 bytes)
# Collecting torchvision==0.14.1 (from LongTermBiosignals)
#   Downloading torchvision-0.14.1-cp310-cp310-macosx_10_9_x86_64.whl.metadata (11 kB)
# Collecting tornado==6.1 (from LongTermBiosignals)
#   Downloading tornado-6.1.tar.gz (497 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.4/497.4 kB 16.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting tqdm==4.64.0 (from LongTermBiosignals)
#   Downloading tqdm-4.64.0-py2.py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 1.7 MB/s eta 0:00:00
# Collecting traces==0.6.0 (from LongTermBiosignals)
#   Downloading traces-0.6.0-py2.py3-none-any.whl.metadata (6.8 kB)
# Collecting traitlets==5.3.0 (from LongTermBiosignals)
#   Downloading traitlets-5.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting twine (from LongTermBiosignals)
#   Using cached twine-5.0.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typepy==1.3.0 (from LongTermBiosignals)
#   Downloading typepy-1.3.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting typing-extensions==4.2.0 (from LongTermBiosignals)
#   Downloading typing_extensions-4.2.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting Unidecode==1.3.6 (from LongTermBiosignals)
#   Downloading Unidecode-1.3.6-py3-none-any.whl.metadata (13 kB)
# Collecting urllib3==1.26.9 (from LongTermBiosignals)
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 1.3 MB/s eta 0:00:00
# Collecting validators==0.20.0 (from LongTermBiosignals)
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting vega-datasets==0.9.0 (from LongTermBiosignals)
#   Downloading vega_datasets-0.9.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting wcwidth==0.2.5 (from LongTermBiosignals)
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl.metadata (11 kB)
# Collecting webencodings==0.5.1 (from LongTermBiosignals)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting wfdb==3.4.1 (from LongTermBiosignals)
#   Downloading wfdb-3.4.1-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: wget==3.2 in ./venv/lib/python3.10/site-packages (from LongTermBiosignals) (3.2)
# Collecting widgetsnbextension==3.6.1 (from LongTermBiosignals)
#   Downloading widgetsnbextension-3.6.1-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting wrapt==1.14.1 (from LongTermBiosignals)
#   Downloading wrapt-1.14.1-cp310-cp310-macosx_10_9_x86_64.whl.metadata (6.7 kB)
# Collecting xarray==2023.12.0 (from LongTermBiosignals)
#   Downloading xarray-2023.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting xmltodict==0.13.0 (from LongTermBiosignals)
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting zipp==3.8.1 (from LongTermBiosignals)
#   Downloading zipp-3.8.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting zope.interface==6.0 (from LongTermBiosignals)
#   Downloading zope.interface-6.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 649.6 kB/s eta 0:00:0000:01
# Requirement already satisfied: setuptools>=20.0 in ./venv/lib/python3.10/site-packages (from astroid==2.11.5->LongTermBiosignals) (58.1.0)
# Collecting setuptools>=20.0 (from astroid==2.11.5->LongTermBiosignals)
#   Using cached setuptools-69.1.1-py3-none-any.whl.metadata (6.2 kB)
# Downloading LongTermBiosignals-2.0.2-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 4.8 MB/s eta 0:00:00
# Downloading alabaster-0.7.12-py2.py3-none-any.whl (14 kB)
# Downloading altair-4.2.0-py3-none-any.whl (812 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.8/812.8 kB 19.1 MB/s eta 0:00:0000:01
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading appnope-0.1.3-py2.py3-none-any.whl (4.4 kB)
# Downloading argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Downloading argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 1.7 MB/s eta 0:00:00
# Downloading astroid-2.11.5-py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.0/251.0 kB 7.2 MB/s eta 0:00:00
# Downloading asttokens-2.0.5-py2.py3-none-any.whl (20 kB)
# Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 1.8 MB/s eta 0:00:00
# Downloading Babel-2.10.3-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 32.5 MB/s eta 0:00:0000:0100:01
# Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Downloading backoff-1.11.1-py2.py3-none-any.whl (13 kB)
# Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 3.8 MB/s eta 0:00:00
# Downloading bidict-0.22.0-py3-none-any.whl (36 kB)
# Downloading bleach-5.0.1-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.9/160.9 kB 5.3 MB/s eta 0:00:00
# Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 32.9 MB/s eta 0:00:0000:0100:01
# Downloading boltons-21.0.0-py2.py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.7/193.7 kB 6.2 MB/s eta 0:00:00
# Downloading certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.2/149.2 kB 4.2 MB/s eta 0:00:00
# Downloading cffi-1.15.0-cp310-cp310-macosx_10_9_x86_64.whl (178 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 4.2 MB/s eta 0:00:00ta 0:00:01
# Downloading cftime-1.6.3-cp310-cp310-macosx_10_9_x86_64.whl (253 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.6/253.6 kB 7.8 MB/s eta 0:00:00
# Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 3.1 MB/s eta 0:00:00ta 0:00:01
# Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Downloading click-8.1.3-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 3.5 MB/s eta 0:00:00
# Downloading click_spinner-0.1.10-py2.py3-none-any.whl (4.0 kB)
# Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Downloading colorspacious-1.1.2-py2.py3-none-any.whl (37 kB)
# Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 1.6 MB/s eta 0:00:00
# Downloading cramjam-2.5.0-cp310-cp310-macosx_10_9_x86_64.macosx_11_0_arm64.macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 4.5 MB/s eta 0:00:0000:0100:01m
# Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Downloading Cython-0.29.32-py2.py3-none-any.whl (986 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 986.3/986.3 kB 20.9 MB/s eta 0:00:0000:01
# Downloading dacite-1.6.0-py3-none-any.whl (12 kB)
# Downloading darkdetect-0.8.0-py3-none-any.whl (9.0 kB)
# Downloading datacommons-1.4.3-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 1.4 MB/s eta 0:00:00
# Downloading datacommons_pandas-0.0.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 791.9 kB/s eta 0:00:00 0:00:01
# Downloading datapane-0.15.3-py3-none-any.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 4.4 MB/s eta 0:00:00a 0:00:01m
# Downloading DateTime-5.1-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 1.7 MB/s eta 0:00:00
# Downloading DateTimeRange-1.2.0-py3-none-any.whl (8.6 kB)
# Downloading debugpy-1.6.0-cp310-cp310-macosx_10_15_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 11.3 MB/s eta 0:00:0000:0100:01
# Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading diagrams-0.21.1-py3-none-any.whl (23.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 20.2 MB/s eta 0:00:0000:0100:01
# Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 2.4 MB/s eta 0:00:00
# Downloading docutils-0.18.1-py2.py3-none-any.whl (570 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.0/570.0 kB 10.2 MB/s eta 0:00:0000:01
# Downloading dominate-2.7.0-py2.py3-none-any.whl (29 kB)
# Downloading dulwich-0.20.46-cp310-cp310-macosx_10_15_x86_64.whl (458 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 458.4/458.4 kB 13.8 MB/s eta 0:00:00
# Downloading EDFlib_Python-1.0.6-py3-none-any.whl (26 kB)
# Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Downloading executing-0.8.3-py2.py3-none-any.whl (16 kB)
# Downloading face-20.1.1-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 802.6 kB/s eta 0:00:00 0:00:01
# Downloading fastjsonschema-2.15.3-py3-none-any.whl (22 kB)
# Downloading fastparquet-0.8.3-cp310-cp310-macosx_10_9_universal2.whl (775 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.3/775.3 kB 7.7 MB/s eta 0:00:00:00:0100:01
# Downloading flake8-5.0.4-py2.py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 1.8 MB/s eta 0:00:00
# Downloading fonttools-4.33.2-py3-none-any.whl (930 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.7/930.7 kB 15.5 MB/s eta 0:00:0000:01
# Downloading fpdf2-2.5.5-py2.py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.7/227.7 kB 5.5 MB/s eta 0:00:00:00:01
# Downloading fsspec-2022.8.2-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.8/140.8 kB 4.6 MB/s eta 0:00:00
# Downloading furl-2.1.3-py2.py3-none-any.whl (20 kB)
# Downloading furo-2022.12.7-py3-none-any.whl (328 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.7/328.7 kB 9.7 MB/s eta 0:00:00
# Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 1.9 MB/s eta 0:00:00
# Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.2/181.2 kB 3.6 MB/s eta 0:00:00ta 0:00:01
# Downloading glom-22.1.0-py2.py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.7/100.7 kB 2.9 MB/s eta 0:00:00
# Downloading graphviz-0.19.2-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 814.2 kB/s eta 0:00:00 0:00:01
# Downloading h5py-3.7.0-cp310-cp310-macosx_10_9_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 11.5 MB/s eta 0:00:0000:0100:01
# Downloading idna-3.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 1.7 MB/s eta 0:00:00
# Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Downloading importlib_metadata-4.12.0-py3-none-any.whl (21 kB)
# Downloading importlib_resources-5.9.0-py3-none-any.whl (33 kB)
# Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Downloading ipykernel-6.15.0-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 2.6 MB/s eta 0:00:00ta 0:00:01
# Downloading ipython-8.4.0-py3-none-any.whl (750 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.8/750.8 kB 13.3 MB/s eta 0:00:0000:01
# Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Downloading ipywidgets-7.7.1-py2.py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 4.2 MB/s eta 0:00:00
# Downloading isort-5.10.1-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.4/103.4 kB 3.4 MB/s eta 0:00:00
# Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 22.1 MB/s eta 0:00:00a 0:00:01
# Downloading Jinja2-3.1.1-py3-none-any.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 4.4 MB/s eta 0:00:00
# Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 kB 7.7 MB/s eta 0:00:00ta 0:00:01
# Downloading jsonschema-4.6.0-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.4/80.4 kB 2.5 MB/s eta 0:00:00
# Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Downloading jupyter_client-7.3.4-py3-none-any.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 4.3 MB/s eta 0:00:00
# Downloading jupyter_console-6.4.4-py3-none-any.whl (22 kB)
# Downloading jupyter_core-4.10.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.3/87.3 kB 2.9 MB/s eta 0:00:00
# Downloading jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Downloading jupyterlab_widgets-1.1.1-py3-none-any.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 7.3 MB/s eta 0:00:00
# Downloading keyring-23.7.0-py3-none-any.whl (34 kB)
# Downloading kiwisolver-1.4.2-cp310-cp310-macosx_10_9_x86_64.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.3/65.3 kB 2.1 MB/s eta 0:00:00
# Downloading lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Downloading lazy_object_proxy-1.7.1-cp310-cp310-macosx_10_9_x86_64.whl (22 kB)
# Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 2.7 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.1-cp310-cp310-macosx_10_9_x86_64.whl (13 kB)
# Downloading matplotlib-3.5.1-cp310-cp310-macosx_10_9_x86_64.whl (7.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 27.5 MB/s eta 0:00:0000:0100:01
# Downloading matplotlib_inline-0.1.3-py3-none-any.whl (8.2 kB)
# Downloading mbstrdecoder-1.1.0-py3-none-any.whl (7.8 kB)
# Downloading mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Downloading mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 1.5 MB/s eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Downloading mne_qt_browser-0.6.1-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 2.4 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Downloading multipledispatch-0.6.0-py3-none-any.whl (11 kB)
# Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Downloading myst_parser-0.18.1-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 1.7 MB/s eta 0:00:00
# Downloading nbclient-0.6.4-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 2.3 MB/s eta 0:00:00
# Downloading nbconvert-6.5.0-py3-none-any.whl (561 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.6/561.6 kB 12.7 MB/s eta 0:00:0000:01
# Downloading nbformat-5.4.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.3/73.3 kB 2.2 MB/s eta 0:00:00
# Downloading neo-0.10.2-py3-none-any.whl (639 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 639.1/639.1 kB 14.4 MB/s eta 0:00:0000:01
# Downloading nest_asyncio-1.5.5-py3-none-any.whl (5.2 kB)
# Downloading netCDF4-1.6.5-cp310-cp310-macosx_10_9_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 25.6 MB/s eta 0:00:0000:0100:01
# Downloading notebook-6.4.12-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 25.3 MB/s eta 0:00:0000:0100:01
# Downloading numexpr-2.8.3-cp310-cp310-macosx_10_9_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.0/99.0 kB 2.6 MB/s eta 0:00:00eta 0:00:01
# Downloading numpy-1.22.3-cp310-cp310-macosx_10_14_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 21.0 MB/s eta 0:00:0000:0100:01
# Downloading opencv_python-4.5.5.64-cp36-abi3-macosx_10_15_x86_64.whl (46.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 MB 24.1 MB/s eta 0:00:0000:0100:01
# Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl (11 kB)
# Downloading outdated-0.2.2-py2.py3-none-any.whl (7.5 kB)
# Downloading packaging-21.3-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 1.2 MB/s eta 0:00:00
# Downloading pandas-1.4.2-cp310-cp310-macosx_10_9_x86_64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 27.3 MB/s eta 0:00:0000:010:01
# Downloading pandas_flavor-0.6.0-py3-none-any.whl (7.2 kB)
# Downloading pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Downloading parso-0.8.3-py2.py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 3.4 MB/s eta 0:00:00
# Downloading patsy-0.5.2-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.7/233.7 kB 7.4 MB/s eta 0:00:00
# Downloading pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 1.8 MB/s eta 0:00:00
# Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Downloading Pillow-9.1.0-cp310-cp310-macosx_10_9_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 23.4 MB/s eta 0:00:0000:0100:01
# Downloading pingouin-0.5.3-py3-none-any.whl (198 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.6/198.6 kB 6.3 MB/s eta 0:00:00
# Downloading pkginfo-1.8.3-py2.py3-none-any.whl (26 kB)
# Downloading platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Downloading plotly-5.10.0-py2.py3-none-any.whl (15.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 16.2 MB/s eta 0:00:0000:0100:01
# Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 1.4 MB/s eta 0:00:00
# Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 1.7 MB/s eta 0:00:00
# Downloading posthog-2.1.2-py2.py3-none-any.whl (32 kB)
# Downloading prometheus_client-0.14.1-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 1.9 MB/s eta 0:00:00
# Downloading prompt_toolkit-3.0.30-py3-none-any.whl (381 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.7/381.7 kB 7.0 MB/s eta 0:00:00:00:01
# Downloading psutil-5.9.1-cp310-cp310-macosx_10_9_x86_64.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.3/239.3 kB 4.6 MB/s eta 0:00:00:00:01
# Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 3.4 MB/s eta 0:00:00
# Downloading pyarrow-6.0.1-cp310-cp310-macosx_10_13_x86_64.whl (19.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 16.7 MB/s eta 0:00:0000:0100:01
# Downloading pycodestyle-2.9.1-py2.py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.5/41.5 kB 1.2 MB/s eta 0:00:00
# Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 3.7 MB/s eta 0:00:00
# Downloading pydantic-1.10.2-cp310-cp310-macosx_10_9_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 17.0 MB/s eta 0:00:0000:0100:01
# Downloading pyEDFlib-0.1.30-cp310-cp310-macosx_10_9_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.1 MB/s eta 0:00:0000:0100:01m
# Downloading pyflakes-2.5.0-py2.py3-none-any.whl (66 kB)
# ...
# Downloading sphinx_basic_ng-1.0.0b1-py3-none-any.whl (22 kB)
# Downloading sphinx_copybutton-0.5.1-py3-none-any.whl (13 kB)
# Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 kB 7.0 MB/s eta 0:00:00
# Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.7/84.7 kB 2.4 MB/s eta 0:00:00
# Downloading sphinxcontrib_htmlhelp-2.0.0-py2.py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.5/100.5 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 2.0 MB/s eta 0:00:00ta 0:00:01
# Downloading sphinxcontrib_serializinghtml-1.1.5-py2.py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 2.3 MB/s eta 0:00:00:00:01
# Downloading stack_data-0.3.0-py3-none-any.whl (23 kB)
# Downloading statsmodels-0.13.2-cp310-cp310-macosx_10_9_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 15.5 MB/s eta 0:00:0000:0100:01
# Downloading tables-3.7.0-cp310-cp310-macosx_10_9_x86_64.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 4.0 MB/s eta 0:00:0000:0100:01m
# Downloading tabulate-0.8.10-py3-none-any.whl (29 kB)
# Downloading tenacity-8.1.0-py3-none-any.whl (23 kB)
# Downloading terminado-0.15.0-py3-none-any.whl (16 kB)
# Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Downloading tinycss2-1.1.1-py3-none-any.whl (21 kB)
# Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 1.7 MB/s eta 0:00:00
# Downloading torch-1.13.1-cp310-none-macosx_10_9_x86_64.whl (135.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 MB 8.4 MB/s eta 0:00:00:00:0100:01
# Downloading torchmetrics-0.10.0-py3-none-any.whl (529 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.2/529.2 kB 9.1 MB/s eta 0:00:00:00:01
# Downloading torchsummary-1.5.1-py3-none-any.whl (2.8 kB)
# Downloading torchvision-0.14.1-cp310-cp310-macosx_10_9_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 13.7 MB/s eta 0:00:0000:0100:01
# Downloading tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 2.4 MB/s eta 0:00:00
# Downloading traces-0.6.0-py2.py3-none-any.whl (18 kB)
# Downloading traitlets-5.3.0-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 3.3 MB/s eta 0:00:00
# Downloading typepy-1.3.0-py3-none-any.whl (31 kB)
# Downloading typing_extensions-4.2.0-py3-none-any.whl (24 kB)
# Downloading Unidecode-1.3.6-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 kB 6.0 MB/s eta 0:00:00:00:01
# Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.0/139.0 kB 1.9 MB/s eta 0:00:00ta 0:00:01
# Downloading vega_datasets-0.9.0-py3-none-any.whl (210 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.8/210.8 kB 4.7 MB/s eta 0:00:00ta 0:00:01
# Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading wfdb-3.4.1-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.6/137.6 kB 2.4 MB/s eta 0:00:00ta 0:00:01
# Downloading widgetsnbextension-3.6.1-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.5 MB/s eta 0:00:0000:0100:01
# Downloading wrapt-1.14.1-cp310-cp310-macosx_10_9_x86_64.whl (35 kB)
# Downloading xarray-2023.12.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.5 MB/s eta 0:00:0000:0100:01
# Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Downloading zipp-3.8.1-py3-none-any.whl (5.6 kB)
# Downloading zope.interface-6.0-cp310-cp310-macosx_10_9_x86_64.whl (202 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.3/202.3 kB 6.0 MB/s eta 0:00:00
# Downloading mne-1.6.1-py3-none-any.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 17.8 MB/s eta 0:00:0000:0100:01
# Downloading pyqtgraph-0.13.4-py3-none-any.whl (975 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 975.2/975.2 kB 12.1 MB/s eta 0:00:0000:0100:01
# Downloading mne_connectivity-0.6.0-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.2/107.2 kB 3.2 MB/s eta 0:00:00
# Downloading PyQt5-5.15.10-cp37-abi3-macosx_10_13_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 19.0 MB/s eta 0:00:0000:0100:01
# Downloading PyQt5_Qt5-5.15.12-py3-none-macosx_10_13_x86_64.whl (38.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.8/38.8 MB 16.6 MB/s eta 0:00:0000:0100:01
# Downloading PyQt5_sip-12.13.0-cp310-cp310-macosx_10_9_universal2.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.4/144.4 kB 4.5 MB/s eta 0:00:00
# Using cached twine-5.0.0-py3-none-any.whl (37 kB)
# Using cached setuptools-69.1.1-py3-none-any.whl (819 kB)
# Building wheels for collected packages: biosppy, future, infinity, lxml, micawber, py-cpuinfo, quantities, stringcase, thriftpy2, tornado, validators
#   Building wheel for biosppy (pyproject.toml) ... done
#   Created wheel for biosppy: filename=biosppy-0.8.0-py2.py3-none-any.whl size=100159 sha256=0573f3aaf80edd80b46f56750d8b78a0dab2600f7c0b57c9b6032a35a57d7a0e
#   Stored in directory: /Users/saraiva/Library/Caches/pip/wheels/86/1c/54/ba65239a6a35020f909f288384dbea820f07d3a9cb164e3cc8
#   Building wheel for future (pyproject.toml) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491058 sha256=1b8ce5358ff9b8490770451c75bc47782b9872832cea66fc2b8eab9af019160a
#   Stored in directory: /Users/saraiva/Library/Caches/pip/wheels/22/73/06/557dc4f4ef68179b9d763930d6eec26b88ed7c389b19588a1c
#   Building wheel for infinity (pyproject.toml) ... done
#   Created wheel for infinity: filename=infinity-1.5-py3-none-any.whl size=3090 sha256=a7741e941ccadf24309e809aaba7d70b9cc98029def93faba28706bf5b7cf78a
#   Stored in directory: /Users/saraiva/Library/Caches/pip/wheels/cb/ba/c7/89592ec56d0923ca07b295d3cf21650e5de21a53cce64f87f9
#   Building wheel for lxml (pyproject.toml) ... done
#   Created wheel for lxml: filename=lxml-4.9.1-cp310-cp310-macosx_10_9_universal2.whl size=2968068 sha256=d745bc3b8706e792d1285f221d430a59f7c6b56bc04f0846cc01e840c7b0c1ce
#   Stored in directory: /Users/saraiva/Library/Caches/pip/wheels/a4/ec/7b/8acde6da24b5aabeee049213d5bec12d1e9214d3cae276387b
#   Building wheel for micawber (pyproject.toml) ... done
#   Created wheel for micawber: filename=micawber-0.5.4-py3-none-any.whl size=22352 sha256=60abad2be15082847eb9239b224e922381d98bcd8d277fa451e9290cceb81a23
#   Stored in directory: /Users/saraiva/Library/Caches/pip/wheels/99/e0/98/6e86b57c00e148e463bf55b7962a3b71b2514d91429efa2789
#   Building wheel for py-cpuinfo (pyproject.toml) ... done
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22243 sha256=a608608b8afba05b618d59e9df15acda14f8d28bdf008624d058658bbb895bcb
#   Stored in directory: /Users/saraiva/Library/Caches/pip/wheels/9a/51/9c/985fe94d3aae45d04bebca10446ca64ad968a750de452ad474
#   Building wheel for quantities (pyproject.toml) ... done
#   Created wheel for quantities: filename=quantities-0.13.0-py3-none-any.whl size=77859 sha256=460fbf7f975d6dd35c23a798bff7614dac55f57c551af1a46f0e1f4ced392b9e
#   Stored in directory: /Users/saraiva/Library/Caches/pip/wheels/f7/c2/4f/df57beba804ab4766843b58de25737b0a7e4774ef139a77c9a
#   Building wheel for stringcase (pyproject.toml) ... done
#   Created wheel for stringcase: filename=stringcase-1.2.0-py3-none-any.whl size=3569 sha256=0af865df5bd8d7e6d8cac43d8cb258e36dc889986185d9248e9eb67374be115f
#   Stored in directory: /Users/saraiva/Library/Caches/pip/wheels/31/ba/22/1a2d952a9ce8aa86e42fda41e2c87fdaf20e238c88bf8df013
#   Building wheel for thriftpy2 (pyproject.toml) ... done
#   Created wheel for thriftpy2: filename=thriftpy2-0.4.14-cp310-cp310-macosx_10_9_universal2.whl size=614711 sha256=78f0bf2b4688502ef5a133b2537588f4c98ef83d14161c23180ab3ac861f4ae9
#   Stored in directory: /Users/saraiva/Library/Caches/pip/wheels/cd/59/69/df7b6cc4ad17732b14a8d7ac4da9ce0504c3b62a5682127326
#   Building wheel for tornado (pyproject.toml) ... done
#   Created wheel for tornado: filename=tornado-6.1-cp310-cp310-macosx_10_9_universal2.whl size=418603 sha256=1e1d41e87cfecccb3c975db5784682ec8ba06f91bce4edf927a9a991c2909cb7
#   Stored in directory: /Users/saraiva/Library/Caches/pip/wheels/80/32/8d/21cf0fa6ee4e083f6530e5b83dfdfa9489a3890d320803f4c7
#   Building wheel for validators (pyproject.toml) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19574 sha256=c1c48342a393307e9ecb50b082d8eeadeecce7aa0c70ea560f8fd0f83766aa16
#   Stored in directory: /Users/saraiva/Library/Caches/pip/wheels/f2/ed/dd/d3a556ad245ef9dc570c6bcd2f22886d17b0b408dd3bbb9ac3
# Successfully built biosppy future infinity lxml micawber py-cpuinfo quantities stringcase thriftpy2 tornado validators
# Installing collected packages: webencodings, wcwidth, torchsummary, stringcase, sortedcontainers, snowballstemmer, Send2Trash, quantities, pytz, PyQt5-Qt5, PyOpenGL, py-cpuinfo, pure-eval, ptyprocess, ply, pickleshare, monotonic, mistune, micawber, littleutils, ipython-genutils, iniconfig, infinity, fastjsonschema, executing, cramjam, commonmark, click-spinner, certifi, boltons, backcall, appnope, appdirs, alabaster, zipp, xmltodict, wrapt, urllib3, Unidecode, typing-extensions, traitlets, tqdm, tornado, toolz, tomli, tinycss2, thriftpy2, threadpoolctl, tenacity, tabulate, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, soupsieve, smmap, six, shortuuid, setuptools, scooby, rfc3986, pyzmq, PyYAML, pyrsistent, PyQt5-sip, pyparsing, Pympler, Pygments, pyflakes, pycparser, pycodestyle, py, psutil, prompt-toolkit, prometheus-client, pluggy, platformdirs, pkginfo, Pillow, pexpect, parso, pandocfilters, numpy, nest-asyncio, multimethod, mdurl, mccabe, MarkupSafe, lxml, lazy-object-proxy, lazy-loader, kiwisolver, keyring, jupyterlab-widgets, jupyterlab-pygments, joblib, isort, importlib-resources, imagesize, idna, graphviz, future, fsspec, fonttools, face, entrypoints, dominate, docutils, dill, defusedxml, decorator, debugpy, darkdetect, dacite, Cython, cycler, colorlog, click, charset-normalizer, chardet, bidict, backoff, Babel, attrs, zope.interface, validators, torch, terminado, scipy, rich, requests, python-dateutil, pyqtgraph, PyQt5, pyEDFlib, pydantic, pyarrow, plotly, patsy, packaging, orderedmultidict, opencv-python, neo, munch, multipledispatch, mbstrdecoder, matplotlib-inline, markdown-it-py, jupyter-core, jsonschema, Jinja2, jedi, importlib-metadata, h5py, glom, gitdb, fpdf2, flake8, EDFlib-Python, edflib, dulwich, datacommons, colorspacious, cftime, cffi, bleach, beautifulsoup4, asttokens, astroid, typepy, traces, torchvision, torchmetrics, stack-data, Sphinx, scikit-learn, requests-toolbelt, readme-renderer, QtPy, pytest, pymatreader, pylint, posthog, pooch, pandas, outdated, numexpr, netCDF4, nbformat, mdit-py-plugins, matplotlib, jupyter-client, GitPython, furl, diagrams, DateTime, bokeh, argon2-cffi-bindings, xarray, wfdb, vega-datasets, twine, tables, statsmodels, sphinx-copybutton, sphinx-basic-ng, sphinx-autoapi, seaborn, QDarkStyle, nbclient, myst-parser, mne, ipython, fastparquet, datacommons-pandas, biosppy, argon2-cffi, altair, plotly-express, pandas-flavor, nbconvert, mne-qt-browser, mne-connectivity, ipykernel, furo, DateTimeRange, qtconsole, pingouin, notebook, jupyter-console, datapane, widgetsnbextension, ipywidgets, jupyter, LongTermBiosignals
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 58.1.0
#     Uninstalling setuptools-58.1.0:
#       Successfully uninstalled setuptools-58.1.0
# Successfully installed Babel-2.10.3 Cython-0.29.32 DateTime-5.1 DateTimeRange-1.2.0 EDFlib-Python-1.0.6 GitPython-3.1.27 Jinja2-3.1.1 LongTermBiosignals-2.0.2 MarkupSafe-2.1.1 Pillow-9.1.0 PyOpenGL-3.1.7 PyQt5-5.15.10 PyQt5-Qt5-5.15.12 PyQt5-sip-12.13.0 PyYAML-6.0 Pygments-2.12.0 Pympler-1.0.1 QDarkStyle-3.2.3 QtPy-2.1.0 Send2Trash-1.8.0 Sphinx-5.0.2 Unidecode-1.3.6 alabaster-0.7.12 altair-4.2.0 appdirs-1.4.4 appnope-0.1.3 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 astroid-2.11.5 asttokens-2.0.5 attrs-21.4.0 backcall-0.2.0 backoff-1.11.1 beautifulsoup4-4.11.1 bidict-0.22.0 biosppy-0.8.0 bleach-5.0.1 bokeh-2.4.3 boltons-21.0.0 certifi-2021.10.8 cffi-1.15.0 cftime-1.6.3 chardet-4.0.0 charset-normalizer-2.0.12 click-8.1.3 click-spinner-0.1.10 colorlog-6.7.0 colorspacious-1.1.2 commonmark-0.9.1 cramjam-2.5.0 cycler-0.11.0 dacite-1.6.0 darkdetect-0.8.0 datacommons-1.4.3 datacommons-pandas-0.0.3 datapane-0.15.3 debugpy-1.6.0 decorator-5.1.1 defusedxml-0.7.1 diagrams-0.21.1 dill-0.3.4 docutils-0.18.1 dominate-2.7.0 dulwich-0.20.46 edflib-0.84.1 entrypoints-0.4 executing-0.8.3 face-20.1.1 fastjsonschema-2.15.3 fastparquet-0.8.3 flake8-5.0.4 fonttools-4.33.2 fpdf2-2.5.5 fsspec-2022.8.2 furl-2.1.3 furo-2022.12.7 future-0.18.2 gitdb-4.0.9 glom-22.1.0 graphviz-0.19.2 h5py-3.7.0 idna-3.3 imagesize-1.4.1 importlib-metadata-4.12.0 importlib-resources-5.9.0 infinity-1.5 iniconfig-1.1.1 ipykernel-6.15.0 ipython-8.4.0 ipython-genutils-0.2.0 ipywidgets-7.7.1 isort-5.10.1 jedi-0.18.1 joblib-1.1.0 jsonschema-4.6.0 jupyter-1.0.0 jupyter-client-7.3.4 jupyter-console-6.4.4 jupyter-core-4.10.0 jupyterlab-pygments-0.2.2 jupyterlab-widgets-1.1.1 keyring-23.7.0 kiwisolver-1.4.2 lazy-loader-0.3 lazy-object-proxy-1.7.1 littleutils-0.2.2 lxml-4.9.1 markdown-it-py-2.1.0 matplotlib-3.5.1 matplotlib-inline-0.1.3 mbstrdecoder-1.1.0 mccabe-0.7.0 mdit-py-plugins-0.3.3 mdurl-0.1.2 micawber-0.5.4 mistune-0.8.4 mne-1.6.1 mne-connectivity-0.6.0 mne-qt-browser-0.6.1 monotonic-1.6 multimethod-1.9.1 multipledispatch-0.6.0 munch-2.5.0 myst-parser-0.18.1 nbclient-0.6.4 nbconvert-6.5.0 nbformat-5.4.0 neo-0.10.2 nest-asyncio-1.5.5 netCDF4-1.6.5 notebook-6.4.12 numexpr-2.8.3 numpy-1.22.3 opencv-python-4.5.5.64 orderedmultidict-1.0.1 outdated-0.2.2 packaging-21.3 pandas-1.4.2 pandas-flavor-0.6.0 pandocfilters-1.5.0 parso-0.8.3 patsy-0.5.2 pexpect-4.8.0 pickleshare-0.7.5 pingouin-0.5.3 pkginfo-1.8.3 platformdirs-2.5.2 plotly-5.10.0 plotly-express-0.4.1 pluggy-1.0.0 ply-3.11 pooch-1.6.0 posthog-2.1.2 prometheus-client-0.14.1 prompt-toolkit-3.0.30 psutil-5.9.1 ptyprocess-0.7.0 pure-eval-0.2.2 py-1.11.0 py-cpuinfo-8.0.0 pyEDFlib-0.1.30 pyarrow-6.0.1 pycodestyle-2.9.1 pycparser-2.21 pydantic-1.10.2 pyflakes-2.5.0 pylint-2.13.9 pymatreader-0.0.32 pyparsing-3.0.8 pyqtgraph-0.13.4 pyrsistent-0.18.1 pytest-7.1.2 python-dateutil-2.8.2 pytz-2022.1 pyzmq-23.2.0 qtconsole-5.3.1 quantities-0.13.0 readme-renderer-35.0 requests-2.27.1 requests-toolbelt-0.9.1 rfc3986-2.0.0 rich-12.5.1 scikit-learn-1.1.0 scipy-1.12.0 scooby-0.9.2 seaborn-0.11.2 setuptools-69.1.1 shortuuid-1.0.9 six-1.16.0 smmap-5.0.0 snowballstemmer-2.2.0 sortedcontainers-2.4.0 soupsieve-2.3.2.post1 sphinx-autoapi-2.0.1 sphinx-basic-ng-1.0.0b1 sphinx-copybutton-0.5.1 sphinxcontrib-applehelp-1.0.2 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-2.0.0 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxcontrib-serializinghtml-1.1.5 stack-data-0.3.0 statsmodels-0.13.2 stringcase-1.2.0 tables-3.7.0 tabulate-0.8.10 tenacity-8.1.0 terminado-0.15.0 threadpoolctl-3.1.0 thriftpy2-0.4.14 tinycss2-1.1.1 tomli-2.0.1 toolz-0.12.0 torch-1.13.1 torchmetrics-0.10.0 torchsummary-1.5.1 torchvision-0.14.1 tornado-6.1 tqdm-4.64.0 traces-0.6.0 traitlets-5.3.0 twine-5.0.0 typepy-1.3.0 typing-extensions-4.2.0 urllib3-1.26.9 validators-0.20.0 vega-datasets-0.9.0 wcwidth-0.2.5 webencodings-0.5.1 wfdb-3.4.1 widgetsnbextension-3.6.1 wrapt-1.14.1 xarray-2023.12.0 xmltodict-0.13.0 zipp-3.8.1 zope.interface-6.0

# %% [markdown]
# ## 1. Load and Explore a Biosignal
# Let's use subject F408 as an example. Consider we will need only the ECGs for this project.

# %%
from ltbio.biosignals.modalities import ECG

code = 'F408'
ecg = ECG.load(f'biosignal/{code}/ecg.biosignal')
ecg
# Out:
# Name: Chest-Abdomen ECG Double-View
# Type: ECG
# Location: Chest
# Number of Channels: 2
# Channels: dry, gel,
# Useful Duration: 0:31:13.400000
# Source: ScientISST Sense
# Events:
# - baseline: [01 Jan, 00:00:01; 01 Jan, 00:00:39]
# - lift: [01 Jan, 00:03:10; 01 Jan, 00:04:15]
# - greetings: [01 Jan, 00:04:49; 01 Jan, 00:05:29]
# - gesticulate: [01 Jan, 00:05:59; 01 Jan, 00:07:40]
# - walk_before: [01 Jan, 00:08:20; 01 Jan, 00:10:31]
# - run: [01 Jan, 00:13:37; 01 Jan, 00:39:08]
# - walk_after: [01 Jan, 00:39:08; 01 Jan, 00:46:52]

# %% [markdown]
# Above we can see a textual description of the biosignal. From this we can gather that it was acquired with a ScientISST Sense device, that it has 2 channels, with 31 minutes of simultaneous recording on both, and that 7 events were annotated on it.
#
# We can also get information about the subject conditions:

# %%
ecg.patient_conditions
# Out:
# (COVID-19 (Infection by SARS-CoV-2): Diagnosed 0.5 years ago.,)

# %% [markdown]
# We can see the subject had COVID approximately half a year ago.
#
# But enough about metadata... Let's get a quick sneak-peak of the ECG signals:

# %%
ecg.preview.plot()

# %% [markdown]
# When using `preview`, you're asking for a 5-second window right in the middle of the time series. This is helpful to quickly get a glimpse of the acquisition. We can notice that the "dry" channel is upside down, so let's invert it:

# %%
ecg.invert('dry')
ecg.preview.plot()

# %% [markdown]
# ## 2. Index a Biosignal
# Awsome! Let's see the ECG when the subject was lifting a chair. Recall the events annotated and their names:

# %%
ecg.events
# Out:
# (baseline: [01 Jan, 00:00:01; 01 Jan, 00:00:39],
#  lift: [01 Jan, 00:03:10; 01 Jan, 00:04:15],
#  greetings: [01 Jan, 00:04:49; 01 Jan, 00:05:29],
#  gesticulate: [01 Jan, 00:05:59; 01 Jan, 00:07:40],
#  walk_before: [01 Jan, 00:08:20; 01 Jan, 00:10:31],
#  run: [01 Jan, 00:13:37; 01 Jan, 00:39:08],
#  walk_after: [01 Jan, 00:39:08; 01 Jan, 00:46:52])

# %% [markdown]
# That's right, we're using the name "lift" for that. We can simply index the Biosignal in that interval, by indexing with the string "lift":

# %%
ecg['lift'].plot()

# %% [markdown]
# Look how we plotted the signals from 03:10 to 04:15, without having to memorize these timestamps.
# In LTBio you can index a Biosignal with almost anything! Event names, Channel names, Datetime intervals, tuples of these, etc. Check [this article](https://ltbio.readthedocs.io/en/latest/learn/basic/ltbio101.html#indexing-a-biosignal)!
# For instance, let's just get the gel electrodes when gesticulating:

# %%
ecg['gel']['gesticulate'].plot()

# %% [markdown]
# ## 3. Process a Biosignal
# LTBio offers a diverse set of post-processing tools.
# Let's just get the gel electrodes first to work on that signal only:

# %%
gel_ecg = ecg['gel']
gel_ecg
# Out:
# Name: Chest-Abdomen ECG Double-View
# Type: ECG
# Location: Chest
# Number of Channels: 1
# Channels: gel,
# Useful Duration: 0:31:13.400000
# Source: ScientISST Sense
# Events:
# - baseline: [01 Jan, 00:00:01; 01 Jan, 00:00:39]
# - lift: [01 Jan, 00:03:10; 01 Jan, 00:04:15]
# - greetings: [01 Jan, 00:04:49; 01 Jan, 00:05:29]
# - gesticulate: [01 Jan, 00:05:59; 01 Jan, 00:07:40]
# - walk_before: [01 Jan, 00:08:20; 01 Jan, 00:10:31]
# - run: [01 Jan, 00:13:37; 01 Jan, 00:39:08]
# - walk_after: [01 Jan, 00:39:08; 01 Jan, 00:46:52]

# %% [markdown]
# Firstly, let's resample it to 100 Hz:

# %%
gel_ecg.resample(100)

# %% [markdown]
# Now let's filter the signal wih a simple FIR passband from 1 to 40 Hz:

# %%
from ltbio.processing.filters import *

passband_filter = FrequencyDomainFilter(FrequencyResponse.FIR, BandType.BANDPASS, (1, 40), order=20)  # design the filter
gel_ecg = passband_filter(gel_ecg)  # apply the filter

gel_ecg.preview.plot()

# %% [markdown]
# Much better! Let's normalize it:

# %%
from ltbio.processing.formaters import Normalizer

normalizer = Normalizer(method='minmax')  # design the normalizer
gel_ecg = normalizer(gel_ecg)

gel_ecg.preview.plot()

# %% [markdown]
# Get to know all the LTBio features in [Learn the Basics](https://ltbio.readthedocs.io/en/latest/learn/learn.html).

# %% [markdown]
# ## 4. Stepping out of LTBio
#
# Biosignal objects can be saved, with all the modifications and processing done so-far, in a single line:

# %%
gel_ecg.save('processed_gel_ecg.biosignal')

# %% [markdown]
# You can also convert it to NumPy array and keep going from there:

# %%
gel_ecg.to_array()
# Out:
# array([[0.28445853, 0.30626376, 0.29909501, ..., 0.45801877, 0.44948128,
#         0.43484543]])

# %% [markdown]
# Or to a Pandas DataFrame:

# %%
gel_ecg.to_dataframe()
# Out:
#                               gel
# 2000-01-01 00:00:01.739  0.284459
# 2000-01-01 00:00:01.749  0.306264
# 2000-01-01 00:00:01.759  0.299095
# 2000-01-01 00:00:01.769  0.303249
# 2000-01-01 00:00:01.779  0.341968
# ...                           ...
# 2000-01-01 00:39:16.279  0.404486
# 2000-01-01 00:39:16.289  0.436191
# 2000-01-01 00:39:16.299  0.458019
# 2000-01-01 00:39:16.309  0.449481
# 2000-01-01 00:39:16.319  0.434845
#
# [235459 rows x 1 columns]

# %% [markdown]
# ________
# © 2023 ScientISST. All rights reserved.
#
# Notebook offered by the [LTBio team](https://github.com/jomy-kk/LTBio).
# Contact: joaomiguelsaraiva@tecnico.ulisboa.pt
